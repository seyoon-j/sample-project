# %%
from network import Network
import os
import time
import pandas as pd

import matplotlib.pyplot as plt

# %%
maindir = os.getcwd()

data = pd.read_csv(maindir + '\idvd_Intel_32_nFET_09.csv')

training_input = data[['Vd','Vg']]
training_ouput = data[['Id']]

# numpy array 로 변경
training_input2 = training_input.to_numpy()
training_ouput2 = training_ouput.to_numpy()


# training
# network class 불러오기

net_size    = [2,5,1]
epoch       = 2000
batch_size  = 30
eta         = 0.05

# def SGD(self, training_data, epochs, mini_batch_size, eta, test_data=None):





# inference
# Vd, Vg input 넣기. think 함수 사용

# %%
net = Network(net_size)
net.SGD(training_input2, epoch, batch_size, eta, test_data= training_input2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e5c4752f3738> in <module>
#       1 net = Network(net_size)
# ----> 2 net.SGD(training_input2, epoch, batch_size, eta, test_data= training_input2)
#
# c:\Users\yoony\Documents\1.NMDL\VS_code\network.py in SGD(self, training_data, epochs, mini_batch_size, eta, test_data)
#      49         epoch, and partial progress printed out.  This is useful for
#      50         tracking progress, but slows things down substantially."""
# ---> 51         if test_data:
#      52             n_test = len(test_data)
#      53             n = len(training_data)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
maindir = os.getcwd()
data = pd.read_excel(maindir + '\DG_trainingdata.xlsx', engine = 'openpyxl')

# %%
from loadData import *

training_filename = r'C:\Users\yoony\Documents\1.NMDL\VS_code\DG_trainingdata.xlsx'
input_whole, output_whole = encoded_data(training_filename)

# %%
input_whole
# Out:
# [array([[-1. ],
#         [-2. ],
#         [ 0.1]]),
#  array([[-0.99],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.98],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.97],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.96],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.95],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.94],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.93],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.92],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.91],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.9],
#         [-2. ],
#         [ 0.1]]),
#  array([[-0.89],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.88],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.87],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.86],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.85],
#         [-2.  ],
#         [ 0.1 ]]),
#  array([[-0.84],
#         [-2.  ],
#         [ 0.1 ]]),
# ...
